# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd
df=pd.read_excel("/content/Product-Sales-Region (1).xlsx")

# %%
df.head()
# Out:
#         Date   Region Product  Quantity  UnitPrice StoreLocation CustomerType  \
# 0 2023-02-23     East  Laptop        14     163.60       Store B    Wholesale
# 1 2024-12-19    South   Phone         1     544.01       Store A       Retail
# 2 2023-05-10    North    Desk        14     346.18       Store B    Wholesale
# 3 2025-02-26  Central   Chair        18     384.82       Store A    Wholesale
# 4 2023-06-24     East    Desk        18     237.76       Store C       Retail
#
#    Discount Salesperson  TotalPrice PaymentMethod Promotion  Returned  \
# 0      0.00         Eva    2290.400        Online  FREESHIP         0
# 1      0.00       Alice     544.010     Gift Card    SAVE10         0
# 2      0.10       Alice    4361.868        Online  WINTER15         0
# 3      0.15       Frank    5887.746     Gift Card  FREESHIP         0
# 4      0.00      Carlos    4279.680        Online    SAVE10         0
#
# ...

# %%
df.tail()
# Out:
#            Date   Region  Product  Quantity  UnitPrice StoreLocation  \
# 1495 2025-02-17     West     Desk        13     134.56       Store D
# 1496 2024-01-11    South    Chair        18     209.75       Store C
# 1497 2024-07-27     East     Desk         1     272.50       Store A
# 1498 2024-12-03  Central  Monitor        14     262.67       Store A
# 1499 2025-05-09     West    Chair        13     221.39       Store D
#
#      CustomerType  Discount Salesperson  TotalPrice PaymentMethod Promotion  \
# 1495       Retail      0.05      Carlos    1661.816   Credit Card  WINTER15
# 1496    Wholesale      0.15       Frank    3209.175    Debit Card  FREESHIP
# 1497    Wholesale      0.00         Eva     272.500     Gift Card  WINTER15
# 1498       Retail      0.05      Carlos    3493.511     Gift Card    SAVE10
# 1499    Wholesale      0.00       Frank    2878.070    Debit Card  FREESHIP
#
#       Returned    OrderID CustomerName  ShippingCost  OrderDate DeliveryDate  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Region', 'Product', 'Quantity', 'UnitPrice', 'StoreLocation',
#        'CustomerType', 'Discount', 'Salesperson', 'TotalPrice',
#        'PaymentMethod', 'Promotion', 'Returned', 'OrderID', 'CustomerName',
#        'ShippingCost', 'OrderDate', 'DeliveryDate', 'RegionManager'],
#       dtype='object')

# %%
df.shape
# Out:
# (1500, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           1500 non-null   datetime64[ns]
#  1   Region         1500 non-null   object
#  2   Product        1500 non-null   object
#  3   Quantity       1500 non-null   int64
#  4   UnitPrice      1500 non-null   float64
#  5   StoreLocation  1500 non-null   object
#  6   CustomerType   1500 non-null   object
#  7   Discount       1500 non-null   float64
#  8   Salesperson    1500 non-null   object
#  9   TotalPrice     1500 non-null   float64
#  10  PaymentMethod  1500 non-null   object
#  11  Promotion      1130 non-null   object
#  12  Returned       1500 non-null   int64
#  13  OrderID        1500 non-null   object
#  14  CustomerName   1500 non-null   object
#  15  ShippingCost   1500 non-null   float64
#  16  OrderDate      1500 non-null   datetime64[ns]
# ...

# %%
df.describe()
# Out:
#                                 Date     Quantity    UnitPrice     Discount  \
# count                           1500  1500.000000  1500.000000  1500.000000
# mean   2024-04-07 21:35:02.400000256    10.410667   298.826947     0.073133
# min              2023-01-01 00:00:00     1.000000     5.520000     0.000000
# 25%              2023-08-20 00:00:00     5.000000   151.020000     0.000000
# 50%              2024-04-08 12:00:00    11.000000   294.740000     0.050000
# 75%              2024-12-07 06:00:00    15.000000   446.702500     0.100000
# max              2025-06-30 00:00:00    20.000000   599.720000     0.150000
# std                              NaN     5.735732   169.100075     0.055979
#
#          TotalPrice     Returned  ShippingCost                      OrderDate  \
# count   1500.000000  1500.000000   1500.000000                           1500
# mean    2919.994952     0.248000     27.507293  2024-04-07 21:35:02.400000256
# ...

# %%
df.isnull().sum()
# Out:
# Date               0
# Region             0
# Product            0
# Quantity           0
# UnitPrice          0
# StoreLocation      0
# CustomerType       0
# Discount           0
# Salesperson        0
# TotalPrice         0
# PaymentMethod      0
# Promotion        370
# Returned           0
# OrderID            0
# CustomerName       0
# ShippingCost       0
# OrderDate          0
# DeliveryDate       0
# RegionManager      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["TotalPrice"].sum()
# Out:
# np.float64(4379992.4285)

# %%
df["TotalPrice"].mean()
# Out:
# np.float64(2919.9949523333335)

# %%
df["TotalPrice"].max()
# Out:
# 11077.0

# %%
df["TotalPrice"].min()
# Out:
# 6.969999999999999

# %%
df["OrderID"].count()
# Out:
# np.int64(1500)

# %%
len(df)
# Out:
# 1500

# %%
df.groupby("Region")["TotalPrice"].sum()
# Out:
# Region
# Central    847153.6845
# East       883633.7180
# North      967957.9800
# South      827768.1870
# West       853478.8590
# Name: TotalPrice, dtype: float64

# %%
df.groupby("Region")["TotalPrice"].mean()
# Out:
# Region
# Central    2814.464068
# East       2841.265974
# North      3132.550097
# South      2805.993854
# West       3005.207250
# Name: TotalPrice, dtype: float64

# %%
df.groupby("Product")["Quantity"].sum()
# Out:
# Product
# Chair      2122
# Desk       2026
# Laptop     2408
# Monitor    2177
# Phone      1970
# Printer    2336
# Tablet     2577
# Name: Quantity, dtype: int64

# %%
df.groupby("PaymentMethod")["TotalPrice"].sum()
# Out:
# PaymentMethod
# Cash           950387.8490
# Credit Card    866483.3745
# Debit Card     770420.6640
# Gift Card      821585.3910
# Online         971115.1500
# Name: TotalPrice, dtype: float64

# %%
df.groupby("CustomerType")["TotalPrice"].sum()
# Out:
# CustomerType
# Retail       2.195526e+06
# Wholesale    2.184467e+06
# Name: TotalPrice, dtype: float64

# %%
import matplotlib.pyplot as plt
df.groupby("Region")["TotalPrice"].sum().plot(kind="bar")

plt.show()

# %%
df.groupby("PaymentMethod")["TotalPrice"].sum().plot(kind="pie", autopct="%1.1f%%")

plt.show()

# %%
df["TotalPrice"].sum()
# Out:
# np.float64(4379992.4285)

# %%
import matplotlib.pyplot as plt

df.groupby("Region")["TotalPrice"].sum().plot(kind="bar")

plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")

plt.show()

# %%
import matplotlib.pyplot as plt

ax = df.groupby("Region")["TotalPrice"].sum().plot(kind="bar")

ax.ticklabel_format(style="plain", axis="y")

plt.show()

# %%
df.groupby("Product")["TotalPrice"].sum()
# Out:
# Product
# Chair      622589.4780
# Desk       555266.6645
# Laptop     684417.2415
# Monitor    651629.3925
# Phone      497162.8510
# Printer    684387.4155
# Tablet     684539.3855
# Name: TotalPrice, dtype: float64

# %%
import matplotlib.pyplot as plt

df.groupby("Product")["TotalPrice"].sum().plot(kind="bar")

plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Total Sales")

plt.show()

# %%
df["PaymentMethod"].value_counts()
# Out:
# PaymentMethod
# Online         323
# Cash           312
# Credit Card    299
# Debit Card     290
# Gift Card      276
# Name: count, dtype: int64

# %%
df.groupby("Product")["TotalPrice"].sum()
# Out:
# Product
# Chair      622589.4780
# Desk       555266.6645
# Laptop     684417.2415
# Monitor    651629.3925
# Phone      497162.8510
# Printer    684387.4155
# Tablet     684539.3855
# Name: TotalPrice, dtype: float64

# %%
df["ShippingCost"].mean()
# Out:
# np.float64(27.507293333333333)
